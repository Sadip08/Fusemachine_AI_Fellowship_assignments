# %% [markdown]
# Basics:
# * Readin Images and Video
# * Image transformations
# * Drawing shapes
# * Putting Text
#
# Advanced:
# * Color Spaces
# * BITWISE operations
# * Masking
# * Edge Detection
# * Histogram Computation
#
# Faces:
# * Face Detection
# * Face Recognition
# * Deep Computer Vision

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

print(cv2.__version__)
